# %% [markdown]
# # Monthly Forecast

# %%
# Required imports
import pandas as pd
import matplotlib.pyplot as plt

# Modeling Package
from neuralprophet import NeuralProphet

# %%
df = pd.read_csv('monthly10.csv')

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 832 entries, 0 to 831
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      832 non-null    object
#  1   y       832 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 19.5+ KB

# %%
df.head()
# Out:
#            ds     y
# 0  1953-04-01  2.83
# 1  1953-05-01  3.05
# 2  1953-06-01  3.11
# 3  1953-07-01  2.93
# 4  1953-08-01  2.95

# %%
df.tail()
# Out:
#              ds     y
# 827  2022-03-01  2.13
# 828  2022-04-01  2.75
# 829  2022-05-01  2.90
# 830  2022-06-01  3.14
# 831  2022-07-01  2.90

# %%
df.describe()
# Out:
#                 y
# count  832.000000
# mean     5.604531
# std      2.927294
# min      0.620000
# 25%      3.450000
# 50%      5.015000
# 75%      7.402500
# max     15.320000

# %%
m = NeuralProphet(
    seasonality_mode='multiplicative', 
    n_changepoints=12, 
    num_hidden_layers=2)

# %%
metrics = m.fit(df, freq="M")
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency MS corresponds to 91.587% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - M
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling weekly seasonality. Run NeuralProphet with weekly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 206
#   0%|          | 0/124 [00:00<?, ?it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 1.25E+00, min: 1.00E-01
#   0%|          | 0/124 [00:00<?, ?it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 8.94E-01, min: 1.00E-01
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 4.82E-01
# Epoch[206/206]: 100%|█| 206/206 [00:11<00:00, 17.27it/s, SmoothL1Loss=0.0019, MA

# %%
future = m.make_future_dataframe(df=df, periods=12)
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency MS corresponds to 91.587% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - M

# %%
forecast = m.predict(df=future)
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency M corresponds to 83.333% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - M
# INFO - (NP.df_utils._infer_frequency) - Major frequency M corresponds to 83.333% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - M

# %%
forecast.head()
# Out:
#           ds     y     yhat1 residual1     trend  season_yearly
# 0 2022-07-31  None  1.622621       NaN  1.603156       0.019798
# 1 2022-08-31  None  1.592848       NaN  1.594800      -0.002003
# 2 2022-09-30  None  1.588497       NaN  1.586714       0.001844
# 3 2022-10-31  None  1.556453       NaN  1.578358      -0.022856
# 4 2022-11-30  None  1.556509       NaN  1.570271      -0.014482

# %% [markdown]
# ### Plotting

# %%
fig_forecast = m.plot(forecast)

# %%
fig_comp = m.plot_components(forecast)

# %% [markdown]
# #### February, April, June, August, October, and December has downward seasonality.

# %%
fig_param = m.plot_parameters()

# %% [markdown]
# ## Validation

# %%
# Manual Split
m = NeuralProphet()
df_train, df_test = m.split_df(df, valid_p=0.2)
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency MS corresponds to 91.587% of the data.
# INFO - (NP.df_utils._infer_frequency) - Dataframe freq automatically defined as MS

# %%
train_metrics = m.fit(df_train)
test_metrics = m.test(df_test)
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency MS corresponds to 91.592% of the data.
# INFO - (NP.df_utils._infer_frequency) - Dataframe freq automatically defined as MS
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling weekly seasonality. Run NeuralProphet with weekly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 222
#   0%|          | 0/122 [00:00<?, ?it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 1.26E-01, min: 2.49E-01
#   0%|          | 0/122 [00:00<?, ?it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 1.26E-01, min: 2.49E-01
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 1.16E-01
# Epoch[222/222]: 100%|█| 222/222 [00:10<00:00, 21.31it/s, SmoothL1Loss=0.00402, M
# INFO - (NP.df_utils._infer_frequency) - Major frequency MS corresponds to 90.964% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - MS
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.003  0.600  0.752

# %%
# Builtin Function

m = NeuralProphet()
metrics = m.fit(df_train, validation_df=df_test)
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency MS corresponds to 91.592% of the data.
# INFO - (NP.df_utils._infer_frequency) - Dataframe freq automatically defined as MS
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling weekly seasonality. Run NeuralProphet with weekly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 222
#   0%|          | 0/122 [00:00<?, ?it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 1.06E-01, min: 2.74E+00
#   0%|          | 0/122 [00:00<?, ?it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 8.92E-02, min: 3.25E+00
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 9.81E-02
# Epoch[222/222]: 100%|█| 222/222 [00:10<00:00, 20.99it/s, SmoothL1Loss=0.00402, M

# %%
fig, ax = plt.subplots(figsize=(20, 8))
ax.plot(metrics["MAE"], '-o', label="Training Loss")  
ax.plot(metrics["MAE_val"], '-r', label="Validation Loss")
ax.legend(loc='center right', fontsize=16)
ax.tick_params(axis='both', which='major', labelsize=20)
ax.set_xlabel("Epoch", fontsize=28)
ax.set_ylabel("Loss", fontsize=28)
ax.set_title("Model Loss (MAE) with Monthly Frequency", fontsize=28)
# Out:
# Text(0.5, 1.0, 'Model Loss (MAE) with Monthly Frequency')
