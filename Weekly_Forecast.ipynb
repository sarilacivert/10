# %% [markdown]
# # Weekly Forecast

# %%
# Required imports
import pandas as pd
import matplotlib.pyplot as plt

# Modeling Package
from neuralprophet import NeuralProphet

# %%
df = pd.read_csv('weekly10.csv')

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3161 entries, 0 to 3160
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   DATE     3161 non-null   object
#  1   WGS10YR  3161 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 74.1+ KB

# %%
df.columns = ['ds', 'y']
list(df.columns.values)
# Out:
# ['ds', 'y']

# %%
df.head()
# Out:
#            ds     y
# 0  1962-01-05  4.03
# 1  1962-01-12  4.06
# 2  1962-01-19  4.11
# 3  1962-01-26  4.10
# 4  1962-02-02  4.10

# %%
df.tail()
# Out:
#               ds     y
# 3156  2022-07-01  3.07
# 3157  2022-07-08  2.96
# 3158  2022-07-15  2.95
# 3159  2022-07-22  2.94
# 3160  2022-07-29  2.75

# %%
df.describe()
# Out:
#                  y
# count  3161.000000
# mean      5.922050
# std       2.992316
# min       0.550000
# 25%       3.910000
# 50%       5.730000
# 75%       7.670000
# max      15.680000

# %%
m = NeuralProphet(
    seasonality_mode='multiplicative')
#, 
#    n_changepoints=12, 
#   num_hidden_layers=2)

# %%
metrics = m.fit(df, freq="M")
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency W-FRI corresponds to 99.968% of the data.
# WARNING - (NP.df_utils._infer_frequency) - Defined frequency M is different than major frequency W-FRI
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling weekly seasonality. Run NeuralProphet with weekly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 32
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 139
#   0%|          | 0/137 [00:00<?, ?it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 3.62E-02, min: 1.03E+00
#   0%|          | 0/137 [00:00<?, ?it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 3.62E-02, min: 1.03E+00
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 5.08E-02
# Epoch[139/139]: 100%|█| 139/139 [00:15<00:00,  8.91it/s, SmoothL1Loss=0.00206, M

# %%
future = m.make_future_dataframe(df=df, periods=12)
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency W-FRI corresponds to 99.968% of the data.
# WARNING - (NP.df_utils._infer_frequency) - Defined frequency M is different than major frequency W-FRI

# %%
forecast = m.predict(df=future)
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency M corresponds to 83.333% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - M
# INFO - (NP.df_utils._infer_frequency) - Major frequency M corresponds to 83.333% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - M

# %%
forecast.head()
# Out:
#           ds     y     yhat1 residual1     trend  season_yearly
# 0 2022-07-31  None  1.730647       NaN  1.715374       0.013106
# 1 2022-08-31  None  1.718036       NaN  1.709069       0.007737
# 2 2022-09-30  None  1.705428       NaN  1.702966       0.002135
# 3 2022-10-31  None  1.688037       NaN  1.696661      -0.007521
# 4 2022-11-30  None  1.668617       NaN  1.690559      -0.019238

# %% [markdown]
# ### Plotting

# %%
fig_forecast = m.plot(forecast)

# %%
fig_comp = m.plot_components(forecast)

# %% [markdown]
# #### February, April, June, August, October, and December has downward seasonality.

# %%
fig_param = m.plot_parameters()

# %% [markdown]
# ## Validation

# %%
# Manual Split
m = NeuralProphet()
df_train, df_test = m.split_df(df, valid_p=0.2)
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency W-FRI corresponds to 99.968% of the data.
# INFO - (NP.df_utils._infer_frequency) - Dataframe freq automatically defined as W-FRI

# %%
train_metrics = m.fit(df_train)
test_metrics = m.test(df_test)
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency W-FRI corresponds to 99.96% of the data.
# INFO - (NP.df_utils._infer_frequency) - Dataframe freq automatically defined as W-FRI
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling weekly seasonality. Run NeuralProphet with weekly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 32
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 148
#   0%|          | 0/135 [00:00<?, ?it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 6.08E-01, min: 1.29E-01
#   0%|          | 0/135 [00:00<?, ?it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 5.12E-02, min: 2.09E+00
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 1.46E-01
# Epoch[148/148]: 100%|█| 148/148 [00:13<00:00, 11.08it/s, SmoothL1Loss=0.00235, M
# INFO - (NP.df_utils._infer_frequency) - Major frequency W-FRI corresponds to 99.842% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - W-FRI
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.003  0.672  0.810

# %%
# Builtin Function

m = NeuralProphet()
metrics = m.fit(df_train, validation_df=df_test)
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency W-FRI corresponds to 99.96% of the data.
# INFO - (NP.df_utils._infer_frequency) - Dataframe freq automatically defined as W-FRI
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling weekly seasonality. Run NeuralProphet with weekly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 32
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 148
#   0%|          | 0/135 [00:00<?, ?it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 6.97E-02, min: 2.85E+00
#   0%|          | 0/135 [00:00<?, ?it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 5.12E-02, min: 8.28E-01
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 7.09E-02
# Epoch[148/148]: 100%|█| 148/148 [00:13<00:00, 10.95it/s, SmoothL1Loss=0.00235, M

# %%
fig, ax = plt.subplots(figsize=(20, 8))
ax.plot(metrics["MAE"], '-o', label="Training Loss")  
ax.plot(metrics["MAE_val"], '-r', label="Validation Loss")
ax.legend(loc='center right', fontsize=16)
ax.tick_params(axis='both', which='major', labelsize=20)
ax.set_xlabel("Epoch", fontsize=28)
ax.set_ylabel("Loss", fontsize=28)
ax.set_title("Model Loss (MAE) with Weekly Frequency", fontsize=28)
# Out:
# Text(0.5, 1.0, 'Model Loss (MAE) with Weekly Frequency')
